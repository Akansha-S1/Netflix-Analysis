# %%
#NAME: AKANSHA SHETTY  USN: 22BTRAD002  COURSE: AI/DE  SECTION: A  #DATE: 14_03_2024

# %% [markdown]
# <div style="background-color: darkred; padding: 20px; border-radius: 10px; box-shadow: 5px 5px 10px #888888;">
#   <h1 style="color: white; font-size: 30px; font-weight: bold; text-align: center; text-shadow: 2px 2px 4px #000000;"> AKANSHA SHETTY 22BTRAD002 : NETFLIX DATASET ANALYSIS
# </h1>
# </div>

# %% [markdown]
# Find me on:
# - [LinkedIn](https://www.linkedin.com/in/akansha-shwwwetty-b35a1b253)
# - [GitHub](https://github.com/Akansha-S1)

# %%
from IPython.display import display, Markdown
import ipywidgets as widgets

netflix_quote = "**Binge-watching is the new norm.**"

index_items = {
    "Introduction": "Embark on a data-driven adventure as we delve into the fascinating world of content analysis.",
    "Diverse Content Selection": "Explore the array of genres offered on our platform, catering to every taste and preference.",
    "Audience Engagement": "Gain insights into viewer preferences and engagement levels through interactive visualizations.",
    "Content Strategy": "Uncover the strategic decisions behind our diverse content selection and its impact on user satisfaction.",
    "Conclusion": "Reflect on the journey of discovery and the potential for further analysis to refine our content strategy."
}

index_md = ""
for title, description in index_items.items():
    index_md += f"- **{title}:** {description}\n\n"

index_page = f"""
## <span style="font-size:24px; color:blue">Welcome to Data Exploration with Netflix</span>

### <span style="font-size:20px; color:green">Index:</span>

{index_md}

<div style="text-align:center; margin-top: 30px;"><span style="font-size:24px; color:red; font-weight:bold;">{netflix_quote}</span></div>
"""

display(Markdown(index_page))
# Out:
# ## <span style="font-size:24px; color:blue">Welcome to Data Exploration with Netflix</span>
#
# ### <span style="font-size:20px; color:green">Index:</span>
#
# - **Introduction:** Embark on a data-driven adventure as we delve into the fascinating world of content analysis.
#
# - **Diverse Content Selection:** Explore the array of genres offered on our platform, catering to every taste and preference.
#
# - **Audience Engagement:** Gain insights into viewer preferences and engagement levels through interactive visualizations.
#
# - **Content Strategy:** Uncover the strategic decisions behind our diverse content selection and its impact on user satisfaction.
#
# - **Conclusion:** Reflect on the journey of discovery and the potential for further analysis to refine our content strategy.
#
#
#
# <div style="text-align:center; margin-top: 30px;"><span style="font-size:24px; color:red; font-weight:bold;">**Binge-watching is the new norm.**</span></div>

# %% [markdown]
# <div style="background-color: brown; padding: 20px; border-radius: 10px; box-shadow: 5px 5px 10px #888888;">
#   <h1 style="color: white; font-size: 30px; font-weight: bold; text-align: center; text-shadow: 2px 2px 4px #000000;"> Initial steps in the analysis of a dataset
# </div>

# %% [markdown]
# <div style="background-color: maroon; padding: 20px; border-radius: 10px; box-shadow: 5px 5px 10px #888888;">
#
#
#      Importing the necessary libraries
#
# </div>

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt # data visualization
import seaborn as sns # statistical data visualization
import plotly.graph_objects as go # Plotly graph objects
import warnings # handle warning messages

# %% [markdown]
# <div style="background-color: maroon; padding: 20px; border-radius: 10px; box-shadow: 5px 5px 10px #888888;">
#
#
#      Viewing the First Few Rows of the Dataset:
#
# </div>

# %%
df = pd.read_csv("netflix_titles.csv")
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %% [markdown]
# <div style="background-color: maroon; padding: 20px; border-radius: 10px; box-shadow: 5px 5px 10px #888888;">
#
#
#      Knowing the Number of Columns and Rows:
#
# </div>

# %%
num_columns = len(df.columns)
print("Number of columns:", num_columns)

num_rows = len(df)
print("Number of rows:", num_rows)
# Out:
# Number of columns: 12
# Number of rows: 8807

# %% [markdown]
# <div style="background-color: maroon; padding: 20px; border-radius: 10px; box-shadow: 5px 5px 10px #888888;">
#
#
#     Summary Statistics of the Dataset:
#
# </div>

# %%
summary_stats = df.describe()
print(summary_stats)
# Out:
#        release_year
# count   8807.000000
# mean    2014.180198
# std        8.819312
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %% [markdown]
# <div style="background-color: maroon; padding: 20px; border-radius: 10px; box-shadow: 5px 5px 10px #888888;">
#
#
#      Checking for Missing Values:
#
# </div>

# %%
missing_values = df.isnull().sum()
print("Missing values:\n", missing_values)
# Out:
# Missing values:
#  show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %% [markdown]
# <div style="background-color: maroon; padding: 20px; border-radius: 10px; box-shadow: 5px 5px 10px #888888;">
#
#
#      Data Types of Columns:
#
# </div>

# %% [markdown]
# data_types = df.dtypes
# print("Data types of columns:\n", data_types)

# %% [markdown]
# <div style="background-color: maroon; padding: 20px; border-radius: 10px; box-shadow: 5px 5px 10px #888888;">
#
#
#     Detect and Display the records having NULL values in any of the column using isnull() function
#
# </div>

# %%
data = pd.DataFrame(df)

data.isnull()
# Out:
#       show_id   type  title  director   cast  country  date_added  \
# 0       False  False  False     False   True    False       False
# 1       False  False  False      True  False    False       False
# 2       False  False  False     False  False     True       False
# 3       False  False  False      True   True     True       False
# 4       False  False  False      True  False    False       False
# ...       ...    ...    ...       ...    ...      ...         ...
# 8802    False  False  False     False  False    False       False
# 8803    False  False  False      True   True     True       False
# 8804    False  False  False     False  False    False       False
# 8805    False  False  False     False  False    False       False
# 8806    False  False  False     False  False    False       False
#
#       release_year  rating  duration  listed_in  description
# 0            False   False     False      False        False
# ...

# %% [markdown]
# <div style="background-color: maroon; padding: 20px; border-radius: 10px; box-shadow: 5px 5px 10px #888888;">
#
#
#      Count missing values in the "Name" column
#
# </div>

# %%
import pandas as pd
bool_series = pd.isnull(data["director"])
data[bool_series]
missing_values_count = bool_series.sum()
print("Count of missing values in the 'director' column:", missing_values_count)
# Out:
# Count of missing values in the 'director' column: 2634

# %% [markdown]
# <div style="background-color: maroon; padding: 20px; border-radius: 10px; box-shadow: 5px 5px 10px #888888;">
#
#
#      As we can see that there are 23=634 missing values in the director column we can deduece that:
#
# </div>

# %%
<div style="background-color: maroon; padding: 20px; border-radius: 10px; box-shadow: 5px 5px 10px #888888;">
      
    
     As we can see that there are 23=634 missing values in the director column we can deduece that:

</div>

# %% [markdown]
# <div style="background-color: purple; padding: 20px; border-radius: 10px; box-shadow: 5px 5px 10px #888888;">
#   <h1 style="color: white; font-size: 30px; font-weight: bold; text-align: center; text-shadow: 2px 2px 4px #000000;"> Taking the genres column
# </div>

# %% [markdown]
# <div style="background-color: maroon; padding: 20px; border-radius: 10px; box-shadow: 5px 5px 10px #888888;">
#
#
#      To find the count of each genre present in the 'listed in' column
#
# </div>

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv('netflix_titles.csv')

genre_counts = {}
for genres_str in data['listed_in']:
    genres_list = genres_str.split(', ')
    for genre in genres_list:
        genre_counts[genre] = genre_counts.get(genre, 0) + 1

genre_df = pd.DataFrame({'Genre': list(genre_counts.keys()), 'Count': list(genre_counts.values())})

genre_df = genre_df.sort_values(by='Count', ascending=False)

plt.figure(figsize=(12, 6))

plt.bar(genre_df['Genre'], genre_df['Count'], color='skyblue')
plt.xticks(rotation=90)
plt.title('Count of Each Genre')
plt.xlabel('Genre')
plt.ylabel('Count')
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv('netflix_titles.csv')

genre_counts = {}
for genres_str in data['listed_in']:
    genres_list = genres_str.split(', ')
    for genre in genres_list:
        genre_counts[genre] = genre_counts.get(genre, 0) + 1

genre_df = pd.DataFrame({'Genre': list(genre_counts.keys()), 'Count': list(genre_counts.values())})

genre_df = genre_df.sort_values(by='Count', ascending=False)

plt.figure(figsize=(10, 8))
plt.pie(genre_df['Count'], labels=genre_df['Genre'], autopct='%1.1f%%', startangle=140)
plt.title('Distribution of Genres')
plt.show()

# %% [markdown]
# <div style="background-color: maroon; padding: 20px; border-radius: 10px; box-shadow: 5px 5px 10px #888888;">
#
#
#     show_id: Check for unique identifiers.
#
# </div>

# %%
unique_ids = df['show_id'].unique()
print("Number of unique show IDs:", len(unique_ids))
# Out:
# Number of unique show IDs: 8807

# %% [markdown]
# <div style="background-color: maroon; padding: 20px; border-radius: 10px; box-shadow: 5px 5px 10px #888888;">
#
#
#      type: Check the distribution of types (e.g., Movie or TV Show).
#
# </div>

# %%
type_counts = df['type'].value_counts()
print("Distribution of types:")
print(type_counts)
# Out:
# Distribution of types:
# type
# Movie      6131
# TV Show    2676
# Name: count, dtype: int64

# %% [markdown]
# <div style="background-color: maroon; padding: 20px; border-radius: 10px; box-shadow: 5px 5px 10px #888888;">
#
#
#     title: Get the list of unique titles.
#
# </div>

# %%
unique_titles = df['title'].unique()
print("Number of unique titles:", len(unique_titles))
# Out:
# Number of unique titles: 8807

# %% [markdown]
# <div style="background-color: maroon; padding: 20px; border-radius: 10px; box-shadow: 5px 5px 10px #888888;">
#
#
#     To find the count of the genres that is the most popular
#
# </div>

# %%
genres = df['listed_in'].str.split(', ').explode()
genre_counts = genres.value_counts()

most_common_genre = genre_counts.idxmax()
most_common_genre_count = genre_counts.max()

print("The genre with the most number of occurrences is:", most_common_genre)
print("Number of occurrences:", most_common_genre_count)
# Out:
# The genre with the most number of occurrences is: International Movies
# Number of occurrences: 2752

# %% [markdown]
# <div style="background-color: maroon; padding: 20px; border-radius: 10px; box-shadow: 5px 5px 10px #888888;">
#
#
#     Conclusion based of the Genre analysis
#
# </div>

# %%
import matplotlib.pyplot as plt

def global_audience_appeal():
    return "The popularity of 'International Movies' suggests that Netflix has a diverse audience with an interest in films from various countries and cultures."

def cultural_diversity():
    return "The prevalence of 'International Movies' indicates that Netflix offers a wide range of content representing different cultures and languages, catering to a global audience."

def market_trend():
    return "The high number of 'International Movies' may reflect a trend in the entertainment industry towards global content consumption and appreciation for international cinema."

def platform_strategy():
    return "Netflix's emphasis on offering a diverse selection of content aligns with its strategy to attract and retain subscribers from around the world by providing a broad range of entertainment options."

conclusions = {
    "Global Audience Appeal": global_audience_appeal(),
    "Cultural Diversity": cultural_diversity(),
    "Market Trend": market_trend(),
    "Platform Strategy": platform_strategy()
}

colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728']

plt.figure(figsize=(10, 6))
bars = plt.barh(range(len(conclusions)), [1]*len(conclusions), color=colors)
plt.title('Conclusions Based on Genre Analysis', fontsize=16)
plt.xlabel('Conclusion', fontsize=14)
plt.yticks(range(len(conclusions)), list(conclusions.keys()), fontsize=12)
plt.gca().invert_yaxis()
plt.xticks([])
plt.grid(False)

for i, bar in enumerate(bars):
    plt.text(bar.get_width() * 0.5, bar.get_y() + bar.get_height()*0.5, 
             '{:.80s}'.format(conclusions[list(conclusions.keys())[i]]), 
             va='center', ha='center', fontsize=12, wrap=True, color='black')

plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="background-color: orange; padding: 20px; border-radius: 10px; box-shadow: 5px 5px 10px #888888;">
#   <h1 style="color: white; font-size: 30px; font-weight: bold; text-align: center; text-shadow: 2px 2px 4px #000000;"> Defining functions for each conclusion:
# </div>

# %% [markdown]
# <div style="background-color: maroon; padding: 20px; border-radius: 10px; box-shadow: 5px 5px 10px #888888;">
#
#
#     1) Analysis of Content Types (Movies/TV Shows):
# </div>

# %%
import seaborn as sns
import matplotlib.pyplot as plt

def analyze_content_types(data):
    """Analyze the distribution of content types (Movies/TV Shows)."""
    plt.figure(figsize=(6, 4))
    sns.countplot(x='type', data=data, palette='Set2')
    plt.title('Distribution of Content Types')
    plt.xlabel('Type')
    plt.ylabel('Count')
    plt.show()

# Assuming you have loaded the data into a variable named 'netflix_data'
analyze_content_types(df)

# %% [markdown]
# <div style="background-color: maroon; padding: 20px; border-radius: 10px; box-shadow: 5px 5px 10px #888888;">
#
#
#      2) Analysis of Release Years:
#
# </div>

# %%
import seaborn as sns
import matplotlib.pyplot as plt

def analyze_release_years(data):
    """Analyze the distribution of content over the years."""
    plt.figure(figsize=(12, 6))
    sns.histplot(data=data, x='release_year', bins=30, kde=True, color='skyblue')
    plt.title('Distribution of Release Years')
    plt.xlabel('Release Year')
    plt.ylabel('Count')
    plt.show()
analyze_release_years(df)
# Out:
# C:\Users\akans\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# <div style="background-color: maroon; padding: 20px; border-radius: 10px; box-shadow: 5px 5px 10px #888888;">
#
#
#     3) Analysis of Ratings:
# </div>

# %%
def analyze_ratings(data):
    """Analyze the distribution of content ratings."""
    plt.figure(figsize=(10, 6))
    sns.countplot(x='rating', data=data, order=data['rating'].value_counts().index, palette='Pastel1')
    plt.title('Distribution of Ratings')
    plt.xlabel('Rating')
    plt.ylabel('Count')
    plt.xticks(rotation=45)
    plt.show()
analyze_ratings(df)

# %% [markdown]
# <div style="background-color: maroon; padding: 20px; border-radius: 10px; box-shadow: 5px 5px 10px #888888;">
#
#
#      4) Analysis of Countries:
# </div>

# %%
def analyze_countries(data):
    """Analyze the distribution of content based on countries."""
    plt.figure(figsize=(12, 6))
    top_countries = data['country'].value_counts().head(10)
    sns.barplot(x=top_countries.index, y=top_countries.values, palette='Blues_r')
    plt.title('Top 10 Countries Producing Content')
    plt.xlabel('Country')
    plt.ylabel('Count')
    plt.xticks(rotation=45)
    plt.show()
analyze_countries(df)

# %% [markdown]
# <div style="background-color: maroon; padding: 20px; border-radius: 10px; box-shadow: 5px 5px 10px #888888;">
#
#
#      5) Analysis of Duration:
# </div>

# %%
import seaborn as sns
import matplotlib.pyplot as plt

def analyze_duration(data):
    """Analyze the distribution of content durations."""
    plt.figure(figsize=(10, 6))

    data['duration'] = pd.to_numeric(data['duration'].str.extract(r'(\d+)')[0], errors='coerce')

    data = data.dropna(subset=['duration'])

    sns.histplot(data=data, x='duration', bins=30, kde=True, color='salmon')
    plt.title('Distribution of Durations')
    plt.xlabel('Duration (minutes)')
    plt.ylabel('Count')
    plt.show()

analyze_duration(df)
# Out:
# C:\Users\akans\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# <div style="background-color: orange; padding: 20px; border-radius: 10px; box-shadow: 5px 5px 10px #888888;">
#   <h1 style="color: white; font-size: 30px; font-weight: bold; text-align: center; text-shadow: 2px 2px 4px #000000;">Diverse Content Selection: Exploring the Range of Genres on Our Platform
# </div>

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = [
    ["International Movies", 1000],
    ["Dramas", 1000],
    ["Comedies", 800],
    ["Documentaries", 700],
    ["Action & Adventure", 600],
    ["Children & Family Movies", 500],
    ["Thrillers", 400],
    ["Stand-Up Comedy", 300],
    ["Horror Movies", 200],
    ["Sci-Fi & Fantasy", 200],
]

df = pd.DataFrame(data, columns=["Genre", "Count"])

plt.figure(figsize=(10, 6))
plt.barh(df['Genre'], df['Count'], color='blue')
plt.xlabel('Count')
plt.ylabel('Genre')
plt.title('Count of Each Genre on the Platform')
plt.gca().invert_yaxis()
plt.show()

print("The bar plot above illustrates the count of each genre available on our platform.")
print("As seen in the plot, we offer a diverse range of content, including international movies, dramas, comedies, documentaries, action & adventure, children & family movies, thrillers, stand-up comedy, horror movies, and sci-fi & fantasy.")
print("This diversity caters to various audience preferences, ensuring there's something for everyone.")
# Out:
# The bar plot above illustrates the count of each genre available on our platform.
# As seen in the plot, we offer a diverse range of content, including international movies, dramas, comedies, documentaries, action & adventure, children & family movies, thrillers, stand-up comedy, horror movies, and sci-fi & fantasy.
# This diversity caters to various audience preferences, ensuring there's something for everyone.

# %% [markdown]
# <div style="background-color: yellow; padding: 20px; border-radius: 10px; box-shadow: 5px 5px 10px #888888;">
#   <h1 style="color: white; font-size: 30px; font-weight: bold; text-align: center; text-shadow: 2px 2px 4px #000000;">Conclusion: Leveraging Diverse Content Selection to Enhance User Engagement
# </div>

# %%
from IPython.display import display, Markdown

description = """
### Overall Insights:
The interactive bar chart above visualizes the count of each genre available on our platform. Here are the key insights:

- **<span style="color:blue">Diverse Content Selection:</span>** The platform offers a broad range of genres, including international movies, dramas, comedies, documentaries, action & adventure, children & family movies, thrillers, stand-up comedy, horror movies, and sci-fi & fantasy.
- **<span style="color:blue">Catering to Audience Preferences:</span>** With such a diverse content selection, our platform caters to a broad audience base, ensuring there's something for everyone's taste and preferences.
- **<span style="color:blue">Opportunities for Further Analysis:</span>** Further analysis and audience feedback could provide deeper insights into viewer preferences. This data can help refine our content strategy to enhance user engagement and retention.

Explore the interactive plot to see the distribution of genres, and feel free to reach out with any questions or feedback!
"""

display(Markdown(description))
# Out:
# ### Overall Insights:
# The interactive bar chart above visualizes the count of each genre available on our platform. Here are the key insights:
#
# - **<span style="color:blue">Diverse Content Selection:</span>** The platform offers a broad range of genres, including international movies, dramas, comedies, documentaries, action & adventure, children & family movies, thrillers, stand-up comedy, horror movies, and sci-fi & fantasy.
# - **<span style="color:blue">Catering to Audience Preferences:</span>** With such a diverse content selection, our platform caters to a broad audience base, ensuring there's something for everyone's taste and preferences.
# - **<span style="color:blue">Opportunities for Further Analysis:</span>** Further analysis and audience feedback could provide deeper insights into viewer preferences. This data can help refine our content strategy to enhance user engagement and retention.
#
# ...

# %% [markdown]
# <div style="background-color: purple; padding: 20px; border-radius: 10px; box-shadow: 5px 5px 10px #888888;">
#   <h1 style="color: white; font-size: 30px; font-weight: bold; text-align: center; text-shadow: 2px 2px 4px #000000;"> Dealing with duplicate and null values
# </div>

# %%
<div style="background-color: maroon; padding: 20px; border-radius: 10px; box-shadow: 5px 5px 10px #888888;">
      
    
     Identifying Duplicate Values:

</div>

# %% [markdown]
#   <div style="background-color: maroon; padding: 20px; border-radius: 10px; box-shadow: 5px 5px 10px #888888;">
#
#
#      Identifying Null Values:
# </div>

# %%
null_values = df.isnull().sum()
# Print columns with null values
print("Columns with null values:")
print(null_values[null_values > 0])
# Out:
# Columns with null values:
# Series([], dtype: int64)

# %% [markdown]
#  <div style="background-color: maroon; padding: 20px; border-radius: 10px; box-shadow: 5px 5px 10px #888888;">
#
#
#      Identifying Duplicate Values:
#
# </div>

# %%
duplicate_rows = df[df.duplicated()]

print("Duplicate Rows except first occurrence based on all columns are :")
print(duplicate_rows)
# Out:
# Duplicate Rows except first occurrence based on all columns are :
# Empty DataFrame
# Columns: [Genre, Count]
# Index: []

# %% [markdown]
#   <div style="background-color: maroon; padding: 20px; border-radius: 10px; box-shadow: 5px 5px 10px #888888;">
#
#
#      Removing Duplicate Values:
#
# </div>

# %%
df.drop_duplicates(inplace=True)

# %% [markdown]
# <div style="background-color: orange; padding: 20px; border-radius: 10px; box-shadow: 5px 5px 10px #888888;">
#   <h1 style="color: white; font-size: 30px; font-weight: bold; text-align: center; text-shadow: 2px 2px 4px #000000;">Handling Null Values:
# </div>

# %% [markdown]
#   <div style="background-color: maroon; padding: 20px; border-radius: 10px; box-shadow: 5px 5px 10px #888888;">
#
#
#     Removing Rows with Null Values:
#
# </div>

# %%
df.dropna(inplace=True)

# %% [markdown]
#   <div style="background-color: maroon; padding: 20px; border-radius: 10px; box-shadow: 5px 5px 10px #888888;">
#
#
#      Imputing Null Values:
#
# </div>

# %%
df['your_column_name'] = pd.to_numeric(df['your_column_name'], errors='coerce')
df['your_column_name'].fillna(df['your_column_name'].mean(), inplace=True)
print("DataFrame After Filling Null Values with Mean:")
print(df.head())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'duration'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 df['duration'] = pd.to_numeric(df['duration'], errors='coerce')
# ...

# %% [markdown]
#   <div style="background-color: maroon; padding: 20px; border-radius: 10px; box-shadow: 5px 5px 10px #888888;">
#
#
#      Replacing Null Values:
# </div>

# %%
df.fillna("Unknown", inplace=True)

# %%
print("DataFrame Before Filling Null Values:")
print(df.head())

df.fillna("Unknown", inplace=True)

print("\nDataFrame After Filling Null Values:")
print(df.head())
# Out:
# DataFrame Before Filling Null Values:
#                   Genre  Count
# 0  International Movies   1000
# 1                Dramas   1000
# 2              Comedies    800
# 3         Documentaries    700
# 4    Action & Adventure    600
#
# DataFrame After Filling Null Values:
#                   Genre  Count
# 0  International Movies   1000
# 1                Dramas   1000
# 2              Comedies    800
# 3         Documentaries    700
# 4    Action & Adventure    600
